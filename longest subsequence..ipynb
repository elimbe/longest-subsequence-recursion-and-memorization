# %% [markdown]
# we are given two sequences and we need to find the length of the longest subsequence between them.
# input.
# 1. **sequence 1** : "serendipitous"
# 2. **sequence2**: "precipitation"
#
# output.
# length of the subsequence.

# %%
def len_lcs(seq1,seq2):
    pass

# %% [markdown]
# come up with some sample inputs and outputs and here we try to cover all the edge cases.
# our function should be able to handle all the valid inputs we pass into it. here's a posible list of variations we might encounter.
# 1. general case(string)
# 2. general case(list)
# 3. no common subsequence
# 4. one is a subsequence of the other
# 5. one sequence is empty
# 6. botth sequences are empty
# 7. multiple subsequences with the same length.

# %%
t0={
    'input':{
        'seq1':'serendipitous',
        'seq2':'precipitation'
    },
    'output':7
}
t1={
    'input':{
        'seq1':[1,3,5,6,7,2,5,2,3],
        'seq2':[6,2,4,7,1,5,6,2,3]
        
    },
    'output':5
}
t2={
    'input':{
        'seq1':'longest',
        'seq2':'stone'
    },
    'output':3
}
t3={
    'input':{
        'seq1':'',
        'seq2':''
    },
    'output':0
    
}
t4={
    'input':{
        'seq1':'aakash',
        'seq2':''
    },
    'output':0
}
t5={
    'input':{
        'seq1':'condensed',
        'seq2':'dense'
    },
    'output':5
}
t6={
    'input':{
        'seq1':'aakash',
        'seq2':'optpod'
    },
    'output':0
}
t7={
    'input':{
        'seq1':'abcdef',
        'seq2':'badcfe'
    },
    'output':3
}

# %%
lcs_tests=[t0,t1,t2,t3,t4,t5,t6,t7]

# %% [markdown]
# come up with the correct solution and state it in plain english.

# %% [markdown]
# recursive solution.
# 1. create two counters idx1 and idx2 starting at 0. our recursive function will compute the lcs of the sseq1[indx1:]and seq2[ind2:]
# 2. if seq1[idx1]and seq2[idx2] are equal, then this character belongs to the LCS of seq1[idx1] and seq2[idx2]. further the length this is LCS is one more than LCS of seq1[idx1+1:] and seq2[idx2+1:]
# 3.if not the LCS of seq1[idx1:] and seq2[idx2:] is the longer one among the LCS of seq1[idx1+1],seq2[idx2] and the LCS of seq1[idx1:],seq2[idx2+1:]
# 4. if either seq[idx1:] or seq2[idx2:] is empty, then their LCS is empty.

# %%
def lcs_recursive(seq1,seq2,idx1=0,idx2=0):
    if idx1==len(seq1) or idx2==len(seq2):
        return 0
    elif seq1[idx1]==seq2[idx2]:
        return 1+ lcs_recursive(seq1,seq2, idx1+1,idx2+1)
    else:
        option1=lcs_recursive(seq1,seq2,idx1+1,idx2)
        option2=lcs_recursive(seq1,seq2,idx1,idx2+1)
        return max(option1,option2)

# %%
t0
# Out:
# {'input': {'seq1': 'serendipitous', 'seq2': 'precipitation'}, 'output': 7}

# %%
# %%time
lcs_recursive(t0['input']['seq1'],t0['input']['seq2'])
# Out:
# Wall time: 322 ms
# 7

# %%
from jovian.pythondsa import evaluate_test_cases

# %%
evaluate_test_cases(lcs_recursive,lcs_tests)
# Out:
# TEST CASE #0
#
# Input:
# {'seq1': 'serendipitous', 'seq2': 'precipitation'}
#
# Expected Output:
# 7
#
#
# Actual Output:
# 7
#
# Execution Time:
# 410.067 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'seq1': [1, 3, 5, 6, 7, 2, 5, 2, 3], 'seq2': [6, 2, 4, 7, 1, 5, 6, 2, 3]}
#
# Expected Output:
# 5
#
#
# Actual Output:
# 5
#
# Execution Time:
# 5.296 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'seq1': 'longest', 'seq2': 'stone'}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.227 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'seq1': '', 'seq2': ''}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.003 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'seq1': 'aakash', 'seq2': ''}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'seq1': 'condensed', 'seq2': 'dense'}
#
# ...

# %%
analyse the algorithm complexity and identigy inefficiencies if any.
based on the above, the time complexity is O(2^m+n)

# %%
def lcs_memo(seq1,seq2):
    memo={}
    def recurse(idx1=0,idx2=0):
        key=(idx1,idx2)
        if key in memo:
            return memo[key]

        elif idx1==len(seq1) or idx2==len(seq2):
            memo[key]=0
        elif seq1[idx1]==seq2[idx2]:
            memo[key]=1+recurse(idx1+1,idx2+1)
        else:
            memo[key]=max(recurse(idx1+1,idx2),recurse(idx1,idx2+1))
        return memo[key] 
    return recurse(0,0)

# %%
evaluate_test_cases(lcs_memo, lcs_tests)
# Out:
# TEST CASE #0
#
# Input:
# {'seq1': 'serendipitous', 'seq2': 'precipitation'}
#
# Expected Output:
# 7
#
#
# Actual Output:
# 7
#
# Execution Time:
# 0.238 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'seq1': [1, 3, 5, 6, 7, 2, 5, 2, 3], 'seq2': [6, 2, 4, 7, 1, 5, 6, 2, 3]}
#
# Expected Output:
# 5
#
#
# Actual Output:
# 5
#
# Execution Time:
# 0.102 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'seq1': 'longest', 'seq2': 'stone'}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.054 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'seq1': '', 'seq2': ''}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.003 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'seq1': 'aakash', 'seq2': ''}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.003 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'seq1': 'condensed', 'seq2': 'dense'}
#
# ...
